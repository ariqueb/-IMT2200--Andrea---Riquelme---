# %% [markdown]
# # <img style="float: left; padding-right: 20px; width: 200px" src="https://raw.githubusercontent.com/raxlab/imt2200-data/main/media/logo.jpg">  IMT 2200 - Introducción a Ciencia de Datos
# **Pontificia Universidad Católica de Chile**<br>
# **Instituto de Ingeniería Matemática y Computacional**<br>
# **Semestre 2025-S2**<br>
# **Profesor:** Rodrigo A. Carrasco <br>

# %% [markdown]
# # <h1><center>Actividad 02: Extracción y Revisión de Datos</center></h1>
#
# Esta actividad busca aplicar lo que acabamos de ver en clases sobre extracción de datos y conectarlo con la materia de "Tipos de Datos" que hemos visto en las clases pasadas.

# %% [markdown]
# ## Instrucciones
#
# Esto Notebook contiene las instrucciones a realizar para la actividad.
#
# <b>Al finalizarla, deben subir el Notebook y los archivos generados en un único archivo .zip, al módulo de la Actividad 02 en Canvas.</b>
#
# Para esta actividad deben hacer lo siguiente:
# <ol>
# <li>Extraer datos</li>
#
# Para esta actividad usaremos [**PokeAPI**](https://pokeapi.co/about), una interfaz de código abierto con información detallada relacionada a los videojuegos de Pokémon.
#
# En esta actividad nos concentraremos en comparar las características básicas de los 151 pokémon originales. Para obtener la información de un pokémon, utilizaremos el siguiente URL:
#
# ```
# https://pokeapi.co/api/v2/pokemon/{id_pokemon}
# ```
#
# Donde `{id_pokemon}` es el identificador del pokémon (un número entero).
#
# <br>
#
# <li>Formato</li>
#
# ¿En qué formato están los datos descargados? Identifique si son datos estructurados, semi-estructurados o no estructurados, explicando claramente por qué los categoriza así.
#
# <br>
#
# <li>DataFrame de análisis</li>
#
# Construya un DataFrame con al menos las siguientes columnas: `name, type1, type2, hp, attack, defense, special-attack, special-defense, speed`. En caso de que un pokémon tenga solo un tipo, puede dejar su atributo `type2 = None`. Guarde este nuevo set de datos en un archivo CSV.
#
# **Hint:** Inspeccione el atributo `stats` y `types` de las respuestas obtenidas. El valor que debe almacenar en el DataFrame estará bajó el nombre `base_stat`.
#
# <br>
#
# <li>Preguntas</li>
#
# A partir de su nuevo dataset, responda las siguientes preguntas:
#
# 4.1 ¿Cuál son los 3 tipos (fuego, agua, tierra, etc.) más comunes en los pokémones de la primera generación?
#
# 4.2 ¿Cuál es el pokémon más rápido? ¿Y el más lento?
#
# 4.3 Genere una nueva columna en el DataFrame llamada `total-stats` que consista en la suma de todos los stats de un pokémon (`hp, attack, defense, special-attack, special-defense, speed`) y grafique un histograma de esta nueva variable. ¿Cuál es el rango de valores

# %% [markdown]
# ## Rúbrica
#
# - Si han hecho todo y sólo hay errores menores: 7.0
# - Si sólo llegaron hasta la parte 3: 5.0
# - Menos que eso: 1.0

# %% [markdown]
# ## 1. Extraer datos
#
# Utilizando el URL indicado en el enunciado, obtenga la información de los primeros 151 pokémones y guárdelos en una lista llamada `pokemones`.
#
# Para ello debe usar un `for` que itere sobre los diferentes IDs de pokemon y rescate la información de cada uno de ellos, concatenándola en una lista. Antes de iterar sobre los 151 pokemones, pruebe con 1 o 2 y una vez que verifique que su código está funcionando, aplique a los 151 primeros pokemones.

# %%
import requests
import pandas as pd
import json
import numpy as np
pokemones = []
for i in range(1,152):
    url = f'https://pokeapi.co/api/v2/pokemon/{i}/'
    response = requests.get(url)
    if response.status_code == 200:
        pokemones.append(response.json())
df = pd.json_normalize(pokemones)
df
# Out:
#                                              abilities  base_experience  \
# 0    [{'ability': {'name': 'overgrow', 'url': 'http...               64
# 1    [{'ability': {'name': 'overgrow', 'url': 'http...              142
# 2    [{'ability': {'name': 'overgrow', 'url': 'http...              236
# 3    [{'ability': {'name': 'blaze', 'url': 'https:/...               62
# 4    [{'ability': {'name': 'blaze', 'url': 'https:/...              142
# ..                                                 ...              ...
# 146  [{'ability': {'name': 'shed-skin', 'url': 'htt...               60
# 147  [{'ability': {'name': 'shed-skin', 'url': 'htt...              147
# 148  [{'ability': {'name': 'inner-focus', 'url': 'h...              270
# 149  [{'ability': {'name': 'pressure', 'url': 'http...              306
# 150  [{'ability': {'name': 'synchronize', 'url': 'h...              270
#
#                                                  forms  \
# 0    [{'name': 'bulbasaur', 'url': 'https://pokeapi...
# 1    [{'name': 'ivysaur', 'url': 'https://pokeapi.c...
# 2    [{'name': 'venusaur', 'url': 'https://pokeapi....
# 3    [{'name': 'charmander', 'url': 'https://pokeap...
# 4    [{'name': 'charmeleon', 'url': 'https://pokeap...
# ..                                                 ...
# 146  [{'name': 'dratini', 'url': 'https://pokeapi.c...
# 147  [{'name': 'dragonair', 'url': 'https://pokeapi...
# 148  [{'name': 'dragonite', 'url': 'https://pokeapi...
# 149  [{'name': 'mewtwo', 'url': 'https://pokeapi.co...
# 150  [{'name': 'mew', 'url': 'https://pokeapi.co/ap...
#
#                                           game_indices  height  \
# 0    [{'game_index': 153, 'version': {'name': 'red'...       7
# 1    [{'game_index': 9, 'version': {'name': 'red', ...      10
# 2    [{'game_index': 154, 'version': {'name': 'red'...      20
# 3    [{'game_index': 176, 'version': {'name': 'red'...       6
# 4    [{'game_index': 178, 'version': {'name': 'red'...      11
# ..                                                 ...     ...
# 146  [{'game_index': 88, 'version': {'name': 'red',...      18
# 147  [{'game_index': 89, 'version': {'name': 'red',...      40
# 148  [{'game_index': 66, 'version': {'name': 'red',...      22
# 149  [{'game_index': 131, 'version': {'name': 'red'...      20
# 150  [{'game_index': 21, 'version': {'name': 'red',...       4
#
#                                             held_items   id  is_default  \
# 0                                                   []    1        True
# 1                                                   []    2        True
# 2                                                   []    3        True
# 3                                                   []    4        True
# 4                                                   []    5        True
# ..                                                 ...  ...         ...
# 146  [{'item': {'name': 'dragon-scale', 'url': 'htt...  147        True
# 147  [{'item': {'name': 'dragon-scale', 'url': 'htt...  148        True
# 148  [{'item': {'name': 'dragon-scale', 'url': 'htt...  149        True
# 149                                                 []  150        True
# 150  [{'item': {'name': 'lum-berry', 'url': 'https:...  151        True
#
#                              location_area_encounters  \
# 0      https://pokeapi.co/api/v2/pokemon/1/encounters
# 1      https://pokeapi.co/api/v2/pokemon/2/encounters
# 2      https://pokeapi.co/api/v2/pokemon/3/encounters
# 3      https://pokeapi.co/api/v2/pokemon/4/encounters
# 4      https://pokeapi.co/api/v2/pokemon/5/encounters
# ..                                                ...
# 146  https://pokeapi.co/api/v2/pokemon/147/encounters
# 147  https://pokeapi.co/api/v2/pokemon/148/encounters
# 148  https://pokeapi.co/api/v2/pokemon/149/encounters
# 149  https://pokeapi.co/api/v2/pokemon/150/encounters
# 150  https://pokeapi.co/api/v2/pokemon/151/encounters
#
#                                                  moves  ...  \
# 0    [{'move': {'name': 'razor-wind', 'url': 'https...  ...
# 1    [{'move': {'name': 'swords-dance', 'url': 'htt...  ...
# 2    [{'move': {'name': 'swords-dance', 'url': 'htt...  ...
# 3    [{'move': {'name': 'mega-punch', 'url': 'https...  ...
# 4    [{'move': {'name': 'mega-punch', 'url': 'https...  ...
# ..                                                 ...  ...
# 146  [{'move': {'name': 'bind', 'url': 'https://pok...  ...
# 147  [{'move': {'name': 'bind', 'url': 'https://pok...  ...
# 148  [{'move': {'name': 'mega-punch', 'url': 'https...  ...
# 149  [{'move': {'name': 'mega-punch', 'url': 'https...  ...
# 150  [{'move': {'name': 'pound', 'url': 'https://po...  ...
#
#         sprites.versions.generation-vi.x-y.front_shiny  \
# 0    https://raw.githubusercontent.com/PokeAPI/spri...
# 1    https://raw.githubusercontent.com/PokeAPI/spri...
# 2    https://raw.githubusercontent.com/PokeAPI/spri...
# 3    https://raw.githubusercontent.com/PokeAPI/spri...
# 4    https://raw.githubusercontent.com/PokeAPI/spri...
# ..                                                 ...
# 146  https://raw.githubusercontent.com/PokeAPI/spri...
# 147  https://raw.githubusercontent.com/PokeAPI/spri...
# 148  https://raw.githubusercontent.com/PokeAPI/spri...
# 149  https://raw.githubusercontent.com/PokeAPI/spri...
# 150  https://raw.githubusercontent.com/PokeAPI/spri...
#
#      sprites.versions.generation-vi.x-y.front_shiny_female  \
# 0                                                 None
# 1                                                 None
# 2    https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 146                                               None
# 147                                               None
# 148                                               None
# 149                                               None
# 150                                               None
#
#     sprites.versions.generation-vii.icons.front_default  \
# 0    https://raw.githubusercontent.com/PokeAPI/spri...
# 1    https://raw.githubusercontent.com/PokeAPI/spri...
# 2    https://raw.githubusercontent.com/PokeAPI/spri...
# 3    https://raw.githubusercontent.com/PokeAPI/spri...
# 4    https://raw.githubusercontent.com/PokeAPI/spri...
# ..                                                 ...
# 146  https://raw.githubusercontent.com/PokeAPI/spri...
# 147  https://raw.githubusercontent.com/PokeAPI/spri...
# 148  https://raw.githubusercontent.com/PokeAPI/spri...
# 149  https://raw.githubusercontent.com/PokeAPI/spri...
# 150  https://raw.githubusercontent.com/PokeAPI/spri...
#
#     sprites.versions.generation-vii.icons.front_female  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 146                                               None
# 147                                               None
# 148                                               None
# 149                                               None
# 150                                               None
#
#     sprites.versions.generation-vii.ultra-sun-ultra-moon.front_default  \
# 0    https://raw.githubusercontent.com/PokeAPI/spri...
# 1    https://raw.githubusercontent.com/PokeAPI/spri...
# 2    https://raw.githubusercontent.com/PokeAPI/spri...
# 3    https://raw.githubusercontent.com/PokeAPI/spri...
# 4    https://raw.githubusercontent.com/PokeAPI/spri...
# ..                                                 ...
# 146  https://raw.githubusercontent.com/PokeAPI/spri...
# 147  https://raw.githubusercontent.com/PokeAPI/spri...
# 148  https://raw.githubusercontent.com/PokeAPI/spri...
# 149  https://raw.githubusercontent.com/PokeAPI/spri...
# 150  https://raw.githubusercontent.com/PokeAPI/spri...
#
#     sprites.versions.generation-vii.ultra-sun-ultra-moon.front_female  \
# 0                                                 None
# 1                                                 None
# 2    https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 146                                               None
# 147                                               None
# 148                                               None
# 149                                               None
# 150                                               None
#
#      sprites.versions.generation-vii.ultra-sun-ultra-moon.front_shiny  \
# 0    https://raw.githubusercontent.com/PokeAPI/spri...
# 1    https://raw.githubusercontent.com/PokeAPI/spri...
# 2    https://raw.githubusercontent.com/PokeAPI/spri...
# 3    https://raw.githubusercontent.com/PokeAPI/spri...
# 4    https://raw.githubusercontent.com/PokeAPI/spri...
# ..                                                 ...
# 146  https://raw.githubusercontent.com/PokeAPI/spri...
# 147  https://raw.githubusercontent.com/PokeAPI/spri...
# 148  https://raw.githubusercontent.com/PokeAPI/spri...
# 149  https://raw.githubusercontent.com/PokeAPI/spri...
# 150  https://raw.githubusercontent.com/PokeAPI/spri...
#
#     sprites.versions.generation-vii.ultra-sun-ultra-moon.front_shiny_female  \
# 0                                                 None
# 1                                                 None
# 2    https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 146                                               None
# 147                                               None
# 148                                               None
# 149                                               None
# 150                                               None
#
#     sprites.versions.generation-viii.icons.front_default  \
# 0    https://raw.githubusercontent.com/PokeAPI/spri...
# 1    https://raw.githubusercontent.com/PokeAPI/spri...
# 2    https://raw.githubusercontent.com/PokeAPI/spri...
# 3    https://raw.githubusercontent.com/PokeAPI/spri...
# 4    https://raw.githubusercontent.com/PokeAPI/spri...
# ..                                                 ...
# 146  https://raw.githubusercontent.com/PokeAPI/spri...
# 147  https://raw.githubusercontent.com/PokeAPI/spri...
# 148  https://raw.githubusercontent.com/PokeAPI/spri...
# 149  https://raw.githubusercontent.com/PokeAPI/spri...
# 150  https://raw.githubusercontent.com/PokeAPI/spri...
#
#     sprites.versions.generation-viii.icons.front_female
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 146                                               None
# 147                                               None
# 148                                               None
# 149                                               None
# 150                                               None
#
# [151 rows x 141 columns]

# %% [markdown]
# ## 2. Formato de datos
#
# Revise la lista que almacenó en `pokemones` y coméntenos en qué formato están los datos y qué tipos de datos serían estos (estructurados, semi-estructurados, no estructurados).
#
# Respuesta:

# %% [markdown]
# Se encuentran en formato JSON y son datos semi-estructurados, ya que están organizados por llaves y etiquetas

# %% [markdown]
# ## 3. DataFrame de análisis
#
# Construya ahor un DataFrame para poder analizar los datos posteriormente. Revise las columnas mínimas que debe tener según el enunciado inicial.

# %%
lista_pokemones = []
for index, row in df.iterrows():
    nombre = row['name']
    tipos = row['types']
    type1 = tipos[0]['type']['name']
    type2 = tipos[1]['type']['name'] if len(tipos) > 1 else None

    stats = row['stats']
    pokemon = {
        'name': nombre,
        'type1': type1,
        'type2': type2
    }
    for stat in stats:
        stat_name = stat['stat']['name']
        base_stat = stat['base_stat']
        if stat_name == "hp":
            pokemon['hp'] = base_stat
        elif stat_name == "attack":
            pokemon['attack'] = base_stat
        elif stat_name == "defense":
            pokemon['defense'] = base_stat
        elif stat_name == "special-attack":
            pokemon['special-attack'] = base_stat
        elif stat_name == "special-defense":
            pokemon['special-defense'] = base_stat
        elif stat_name == "speed":
            pokemon['speed'] = base_stat
    lista_pokemones.append(pokemon)
df_final = pd.DataFrame(lista_pokemones)
df_final
# Out:
#            name    type1   type2   hp  attack  defense  special-attack  \
# 0     bulbasaur    grass  poison   45      49       49              65
# 1       ivysaur    grass  poison   60      62       63              80
# 2      venusaur    grass  poison   80      82       83             100
# 3    charmander     fire    None   39      52       43              60
# 4    charmeleon     fire    None   58      64       58              80
# ..          ...      ...     ...  ...     ...      ...             ...
# 146     dratini   dragon    None   41      64       45              50
# 147   dragonair   dragon    None   61      84       65              70
# 148   dragonite   dragon  flying   91     134       95             100
# 149      mewtwo  psychic    None  106     110       90             154
# 150         mew  psychic    None  100     100      100             100
#
#      special-defense  speed
# 0                 65     45
# 1                 80     60
# 2                100     80
# 3                 50     65
# 4                 65     80
# ..               ...    ...
# 146               50     50
# 147               70     70
# 148              100     80
# 149               90    130
# 150              100    100
#
# [151 rows x 9 columns]

# %% [markdown]
# ## 4. Preguntas

# %% [markdown]
# #### 4.1 ¿Cuál son los 3 tipos (*water, fire, ground,* etc.) más comunes en los pokémones de la primera generación?

# %%
tipos_mas_comunes = df_final['type1'].value_counts()
top_3_tipos = tipos_mas_comunes.head(3)
top_3_tipos
# Out:
# type1
# water     28
# normal    22
# poison    14
# Name: count, dtype: int64

# %% [markdown]
# El tipo más común es: water

# %% [markdown]
# #### 4.2 ¿Cuál es el pokémon más rápido? ¿Y el más lento?

# %%
indice_pokemon_mas_rapido = df_final['speed'].idxmax()
indice_pokemon_mas_lento = df_final['speed'].idxmin()
pokemon_mas_rapido = df_final.loc[indice_pokemon_mas_rapido,'name']
pokemon_mas_lento = df_final.loc[indice_pokemon_mas_lento,'name']
print(f"Pokemon más rapido: {pokemon_mas_rapido}, Pokemon más lento: {pokemon_mas_lento}")
# Out:
# Pokemon más rapido: electrode, Pokemon más lento: slowpoke

# %% [markdown]
# El pokémon más rápido es: electrode y el pokemon más lento es slowpoke

# %% [markdown]
# #### 4.3 Genere una nueva columna en el DataFrame llamada `total-stats` que consista en la suma de todos los stats de un pokémon (`hp, attack, defense, special-attack, special-defense, speed`) ¿Cuáles son los valores mínimo y máximo de esta nueva variable?

# %%
total_stats = df_final.iloc[:, 3:].sum(axis=1)
valores_maximo = total_stats.idxmax()
valores_minimo = total_stats.idxmin()
pokemon_maximo = df_final.loc[valores_maximo, 'name']
pokemon_minimo = df_final.loc[valores_minimo, 'name']


print(f" Valor máximo : {pokemon_maximo} - Valor mínimo: {pokemon_minimo}")
# Out:
#  Valor máximo : mewtwo - Valor mínimo: caterpie

# %% [markdown]
# El valor máximo lo tiene:
#
# y el mínimo lo tiene:

# %% [markdown]
# #### 4.4 Grafique un histograma de `total-stats` y comente brevemente lo que observa de la distribución de este atributo.

# %%
import matplotlib.pyplot as plt
total_stats.hist()
plt.show()

# %% [markdown]
# Descripción:
